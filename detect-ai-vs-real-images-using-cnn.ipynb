# %% [markdown]
# # 📦 Imports

# %%
import os
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split
# Out:
# 2026-03-21 18:56:43.958069: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774119404.148270      17 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774119404.205321      17 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774119404.664543      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774119404.664582      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774119404.664585      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774119404.664588      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# # 🧠 Load dataset

# %%
DATASET_PATH = "/kaggle/input/datasets/rhythmghai/ai-vs-real-images-dataset"

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATASET_PATH,
    image_size=(224, 224),
    batch_size=32,
    label_mode='binary'
)
# Out:
# Found 995 files belonging to 2 classes.
# 2026-03-21 18:57:09.971380: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %% [markdown]
# # Normalize

# %%
train_ds = train_ds.map(lambda x, y: (x / 255.0, y))

# %% [markdown]
# # 🧠 Build model

# %%
model = models.Sequential([
    layers.Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    layers.MaxPooling2D(),

    layers.Conv2D(64, (3,3), activation='relu'),
    layers.MaxPooling2D(),

    layers.Conv2D(128, (3,3), activation='relu'),
    layers.MaxPooling2D(),

    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# # Compile

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# # Train

# %%
history = model.fit(train_ds, epochs=5)
# Out:
# Epoch 1/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.5933 - loss: 0.9802
# Epoch 2/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 0.7847 - loss: 0.4401
# Epoch 3/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 0.8249 - loss: 0.3789
# Epoch 4/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 60s 2s/step - accuracy: 0.8720 - loss: 0.3020
# Epoch 5/5
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 82s 2s/step - accuracy: 0.9045 - loss: 0.2218

# %% [markdown]
# # Evaluate

# %%
loss, acc = model.evaluate(train_ds)
print("Accuracy:", acc)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 680ms/step - accuracy: 0.8994 - loss: 0.2069
# Accuracy: 0.8924623131752014

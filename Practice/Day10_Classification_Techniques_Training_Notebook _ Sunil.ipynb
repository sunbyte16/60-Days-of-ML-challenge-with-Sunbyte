# %% [markdown]
# # Day 10 - Classification Techniques
#
# ## Topics Covered
# - Introduction to Classification
# - Logistic Regression
# - Decision Trees
# - Random Forest
# - Confusion Matrix
# - Accuracy
# - Precision
# - Recall
# - F1 Score
#
# This notebook is designed for teaching students with explanations, diagrams, code examples, exercises, and evaluation metrics.

# %% [markdown]
# # Introduction to Classification
#
# ### Classification
# Classification is a Supervised Machine Learning technique used to predict categories.
#
# Examples:
# - Spam vs Not Spam
# - Pass vs Fail
# - Disease vs No Disease
#
# Key Concepts:
# - Features
# - Labels
# - Decision Boundaries

# %%
from sklearn.datasets import load_iris
import pandas as pd

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # Logistic Regression
#
# ### Logistic Regression
# Used for Classification despite its name.
#
# Important Concepts:
# - Sigmoid Function
# - Probability Output (0 to 1)
# - Threshold = 0.5
# - Linear Decision Boundary

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
    data.data, data.target, test_size=0.2, random_state=42
)

model = LogisticRegression(max_iter=5000)
model.fit(X_train, y_train)

pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.956140350877193

# %% [markdown]
# # Decision Tree
#
# ### Decision Tree
# Tree-based algorithm that makes decisions using rules.
#
# Concepts:
# - Root Node
# - Internal Node
# - Leaf Node
# - Entropy
# - Information Gain

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

tree = DecisionTreeClassifier(max_depth=4, random_state=42)
tree.fit(X_train, y_train)

tree_pred = tree.predict(X_test)
print("Accuracy:", accuracy_score(y_test, tree_pred))
# Out:
# Accuracy: 0.9473684210526315

# %% [markdown]
# # Random Forest
#
# ### Random Forest
# Ensemble of multiple Decision Trees.
#
# Advantages:
# - Reduces Overfitting
# - Higher Accuracy
# - Robust Predictions
# - Feature Importance

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train, y_train)

rf_pred = rf.predict(X_test)
print("Accuracy:", accuracy_score(y_test, rf_pred))
# Out:
# Accuracy: 0.9649122807017544

# %% [markdown]
# # Confusion Matrix
#
# ### Confusion Matrix
#
# - TP = True Positive
# - TN = True Negative
# - FP = False Positive
# - FN = False Negative

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, rf_pred)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %% [markdown]
# # Accuracy, Precision, Recall, F1
#
# ### Evaluation Metrics
#
# Accuracy = (TP+TN)/(TP+TN+FP+FN)
#
# Precision = TP/(TP+FP)
#
# Recall = TP/(TP+FN)
#
# F1 = 2*(Precision*Recall)/(Precision+Recall)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, rf_pred))
print("Precision:", precision_score(y_test, rf_pred))
print("Recall   :", recall_score(y_test, rf_pred))
print("F1 Score :", f1_score(y_test, rf_pred))
# Out:
# Accuracy : 0.9649122807017544
# Precision: 0.958904109589041
# Recall   : 0.9859154929577465
# F1 Score : 0.9722222222222222

# %% [markdown]
# # Student Activity
#
# ## Exercise 1
# Train Logistic Regression and compare with Decision Tree.
#
# ## Exercise 2
# Change max_depth in Decision Tree and observe overfitting.
#
# ## Exercise 3
# Change n_estimators in Random Forest and compare performance.
#
# ## Discussion Questions
# 1. When should Precision be prioritized?
# 2. When should Recall be prioritized?
# 3. Why is F1 Score useful?
# 4. Why can Accuracy be misleading?

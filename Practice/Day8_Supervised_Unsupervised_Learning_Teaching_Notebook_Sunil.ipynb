# %% [markdown]
# # Supervised & Unsupervised Learning - Teaching Notebook
#
# This notebook is designed for classroom teaching with explanations, examples, activities, and code.

# %% [markdown]
# ## Linear Regression

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# Sample dataset
data = pd.DataFrame({
    'Hours_Studied':[1,2,3,4,5,6],
    'Score':[35,45,50,60,75,85]
})

X = data[['Hours_Studied']]
y = data['Score']

model = LinearRegression()
model.fit(X,y)

pred = model.predict([[7]])
print("Predicted Score for 7 hours:", pred[0])

plt.figure(figsize=(6,4))
plt.scatter(X,y)
plt.plot(X, model.predict(X))
plt.xlabel("Hours Studied")
plt.ylabel("Score")
plt.title("Linear Regression")
plt.show()
# Out:
# Predicted Score for 7 hours: 93.33333333333334
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Classification using Logistic Regression

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

data = pd.DataFrame({
    'Hours':[1,2,3,4,5,6,7,8],
    'Pass':[0,0,0,0,1,1,1,1]
})

X = data[['Hours']]
y = data['Pass']

model = LogisticRegression()
model.fit(X,y)

prediction = model.predict([[6]])
print("Pass Prediction:", prediction[0])
# Out:
# Pass Prediction: 1
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import pandas as pd

data = pd.DataFrame({
    'X':[1,2,1,2,8,9,8,9],
    'Y':[1,1,2,2,8,8,9,9]
})

kmeans = KMeans(n_clusters=2, random_state=42)
data['Cluster'] = kmeans.fit_predict(data[['X','Y']])

plt.figure(figsize=(6,4))
plt.scatter(data['X'], data['Y'], c=data['Cluster'])
plt.title("K-Means Clustering")
plt.show()
